# %% [markdown]
# # mehmetfatihdata

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
from scipy.stats.mstats import winsorize
from scipy.stats.mstats import ttest_ind
warnings.filterwarnings('ignore')

# %%
students = pd.read_csv("StudentsPerformance.csv")
students.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # Q1:
# Sınavlardaki performans cinsiyete, kökene ve anne-baba eğitim durumuna göre değişiklik göstermekte midir?

# %%
students["total_score"]=(students["math score"]+students["reading score"]+students["writing score"])/3
baslik_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
eksen_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }

# %%
plt.figure(figsize=(16,5))

plt.subplot(1,3,1)
sns.barplot(students["gender"], students["total_score"])
plt.title("Cinsiyete Göre Ortalama Sınav Sonucu", fontdict = baslik_font)

plt.subplot(1,3,2)
sns.barplot(students["race/ethnicity"], students["total_score"])
plt.title("Etnik Kökene Göre Ortalama Sınav Sonucu", fontdict = baslik_font)

plt.subplot(1,3,3)
chart=sns.barplot(students["parental level of education"], students["total_score"])
plt.title("Ebevyn Eğitim Durumuna Göre Ortalama Sınav Sonucu", fontdict = baslik_font )
chart.set_xticklabels(chart.get_xticklabels(), rotation=70)
plt.show()

# %% [markdown]
# # Q2:
# Öğle yemek tipinin sınav performansları ile bir ilişkisi var mı? Varsa bunu nasıl açıklayabilirsiniz?

# %%
plt.figure(figsize=(8,3))

plt.subplot(1,3,3)
sns.barplot(students["lunch"], students["total_score"])
plt.title("Öğle Yemeğinin Durumuna Göre Ortalama Sınav Sonucu", fontdict = baslik_font )
plt.show()

# %% [markdown]
# # Q3:
# Hazırlık kurslarının sınav performansı üzerinde bir etkisi var mı?

# %%
plt.figure(figsize=(8,3))

plt.subplot(1,3,3)
sns.barplot(students["test preparation course"], students["total_score"])
plt.title("Hazırlık Testlerinin Durumuna Göre Ortalama Sınav Sonucu", fontdict = baslik_font )
plt.show()

# %% [markdown]
# # Q3:
# Birbiriyle korelasyonu en fazla olan dersler hangisidir?

# %%
korelasyon=students.corr()

# %%
plt.figure(figsize=(8,5))

sns.heatmap(korelasyon, square=True, annot=True, linewidths=5, vmin=0.8, vmax=1, cmap='viridis')
plt.title("Korelasyon Matrisi (Öğrenci Notları)", fontdict=baslik_font)
plt.ylim(0,len(korelasyon))
plt.show()

# %%
ttest_ind(students["math score"], students["reading score"])
# Out:
# Ttest_indResult(statistic=-4.627084038100885, pvalue=3.946445546433674e-06)

# %% [markdown]
# BİTTİ.
